# %%
# !python -m spacy download en_core_web_lg
# %pip install spacy

# %% [markdown]
# Importing the functions from the functions.py file

# %%
from func import *

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Loading the data

# %%
platform = "1kaggle"
if platform=="kaggle":
    df1 = pd.read_json("/kaggle/input/cgas-assignment1-data/recipe_ingredients.json")
    df2 = pd.read_json("/kaggle/input/cgas-assignment1-data/recipe_ingredients_2ndhalf.json")
    recipe_ingredient_pair = "/kaggle/input/cgas-assignment1-data/results/recipe_ingredient_pairs.txt"
else:
    df1 = pd.read_json("Scraped Data/recipe_ingredients.json")
    df2 = pd.read_json("Scraped Data/recipe_ingredients_2ndhalf.json")
    recipe_ingredient_pair = "recipe_ingredient_pairs.txt"

# %% [markdown]
# Since the data has 12k columns instead of rows, we transpose it

# %%
df1 = df1.transpose()
df1.reset_index(drop=True, inplace=True)

# %%
df2 = df2.transpose()
df2.reset_index(drop=True, inplace=True)

# %%
df = pd.concat([df1,df2])
df
# Out:
#                                         recipe_name  \
# 0     Super Easy Slow Cooker Chicken Enchilada Meat
# 1                               Avocado Quick Bread
# 2                  Quick and Easy Baked Fish Fillet
# 3                                  Roasted Kohlrabi
# 4                               Custard Buttercream
# ...                                             ...
# 6186                      Chocolate Potato Chip Pie
# 6187        New Orleans Chocolate Bourbon Pecan Pie
# 6188                              Microwave Popcorn
# 6189               Grilled Tilapia with Mango Salsa
# 6190                              Cherry Mash Candy
#
#                                                     url  \
# 0     https://www.allrecipes.com/recipe/228367/super...
# 1     https://www.allrecipes.com/recipe/27341/avocad...
# 2     https://www.allrecipes.com/recipe/256348/quick...
# 3     https://www.allrecipes.com/recipe/203975/roast...
# 4     https://www.allrecipes.com/recipe/262379/custa...
# ...                                                 ...
# 6186  https://www.allrecipes.com/chocolate-potato-ch...
# 6187  https://www.allrecipes.com/recipe/130565/new-o...
# 6188  https://www.allrecipes.com/recipe/87305/microw...
# 6189  https://www.allrecipes.com/recipe/166771/grill...
# 6190  https://www.allrecipes.com/recipe/34194/cherry...
#
#                                      recipe_Ingredients  \
# 0     [2 cups chicken broth, 1 (14.5 ounce) can dice...
# 1     [2.6666667461395 cups all-purpose flour, 1.5 t...
# 2     [1 pound flounder fillets, 0.5 teaspoon salt, ...
# 3     [4 kohlrabi bulbs, peeled, 1 tablespoon olive ...
# 4     [1 egg, 1 cup white sugar, 0.5 cup milk, 1.333...
# ...                                                 ...
# 6186  [Crust:, 1 (16 ounce) bag kettle-cooked potato...
# 6187  [0.66666668653488 cup white sugar, 1 cup corn ...
# 6188  [0.5 cup unpopped popcorn, 1 teaspoon vegetabl...
# 6189  [0.33333334326744 cup extra-virgin olive oil, ...
# 6190  [2 cups white sugar, 1.25 cups miniature marsh...
#
#                                            Instructions             cuisine  \
# 0     [{'@type': 'HowToStep', 'text': 'Place chicken...  [Mexican Inspired]
# 1     [{'@type': 'HowToStep', 'text': 'Preheat the o...          [American]
# 2     [{'@type': 'HowToStep', 'image': [{'@type': 'I...          [American]
# 3     [{'@type': 'HowToStep', 'text': 'Preheat the o...          [American]
# 4     [{'@type': 'HowToStep', 'text': 'Beat egg with...            [German]
# ...                                                 ...                 ...
# 6186  [{'@type': 'HowToStep', 'text': 'Preheat the o...          [American]
# 6187  [{'@type': 'HowToStep', 'text': 'Preheat the o...          [Southern]
# 6188  [{'@type': 'HowToStep', 'image': [{'@type': 'I...          [American]
# 6189  [{'@type': 'HowToStep', 'text': 'Prepare the f...          [American]
# 6190  [{'@type': 'HowToStep', 'text': 'Gather all in...    [U.S., American]
#
#      prep_time
# 0       PT480M
# 1        PT60M
# 2        PT25M
# 3        PT20M
# 4        PT10M
# ...        ...
# 6186     PT45M
# 6187     PT50M
# 6188      PT3M
# 6189     PT10M
# 6190     PT10M
#
# [12184 rows x 6 columns]

# %% [markdown]
# # 1a. Preprocessing the data (CSV SAVED)

# %%
df['recipe_id'] = range(1, len(df) + 1)
cols = ['recipe_id'] + [col for col in df.columns if col != 'recipe_id']
df = df[cols]
df = extract_instruction_text(df)
df = extract_prep_time_minutes(df)
df['recipe_Ingredients'] = df['recipe_Ingredients'].apply(list_to_string)
df.to_csv("recipe_dataset")
df
# Out:
#       recipe_id                                    recipe_name  \
# 0             1  Super Easy Slow Cooker Chicken Enchilada Meat
# 1             2                            Avocado Quick Bread
# 2             3               Quick and Easy Baked Fish Fillet
# 3             4                               Roasted Kohlrabi
# 4             5                            Custard Buttercream
# ...         ...                                            ...
# 6186      12180                      Chocolate Potato Chip Pie
# 6187      12181        New Orleans Chocolate Bourbon Pecan Pie
# 6188      12182                              Microwave Popcorn
# 6189      12183               Grilled Tilapia with Mango Salsa
# 6190      12184                              Cherry Mash Candy
#
#                                                     url  \
# 0     https://www.allrecipes.com/recipe/228367/super...
# 1     https://www.allrecipes.com/recipe/27341/avocad...
# 2     https://www.allrecipes.com/recipe/256348/quick...
# 3     https://www.allrecipes.com/recipe/203975/roast...
# 4     https://www.allrecipes.com/recipe/262379/custa...
# ...                                                 ...
# 6186  https://www.allrecipes.com/chocolate-potato-ch...
# 6187  https://www.allrecipes.com/recipe/130565/new-o...
# 6188  https://www.allrecipes.com/recipe/87305/microw...
# 6189  https://www.allrecipes.com/recipe/166771/grill...
# 6190  https://www.allrecipes.com/recipe/34194/cherry...
#
#                                      recipe_Ingredients  \
# 0     2 cups chicken broth, 1 (14.5 ounce) can diced...
# 1     2.6666667461395 cups all-purpose flour, 1.5 te...
# 2     1 pound flounder fillets, 0.5 teaspoon salt, g...
# 3     4 kohlrabi bulbs, peeled, 1 tablespoon olive o...
# 4     1 egg, 1 cup white sugar, 0.5 cup milk, 1.3333...
# ...                                                 ...
# 6186  Crust:, 1 (16 ounce) bag kettle-cooked potato ...
# 6187  0.66666668653488 cup white sugar, 1 cup corn s...
# 6188  0.5 cup unpopped popcorn, 1 teaspoon vegetable...
# 6189  0.33333334326744 cup extra-virgin olive oil, 1...
# 6190  2 cups white sugar, 1.25 cups miniature marshm...
#
#                                            Instructions             cuisine  \
# 0     Place chicken broth, tomatoes, flour, chili po...  [Mexican Inspired]
# 1     Preheat the oven to 350 degrees F (175 degrees...          [American]
# 2     Gather all ingredients. Preheat the oven to 40...          [American]
# 3     Preheat the oven to 450 degrees F (230 degrees...          [American]
# 4     Beat egg with a fork in a small, heavy saucepa...            [German]
# ...                                                 ...                 ...
# 6186  Preheat the oven to 350 degrees F (175 degrees...          [American]
# 6187  Preheat the oven to 375 degrees F (190 degrees...          [Southern]
# 6188  Gather all ingredients. Mix together unpopped ...          [American]
# 6189  Prepare the fish: Whisk together olive oil, le...          [American]
# 6190  Gather all ingredients. Generously grease a 9x...    [U.S., American]
#
#       Prep Time in Minutes
# 0                      480
# 1                       60
# 2                       25
# 3                       20
# 4                       10
# ...                    ...
# 6186                    45
# 6187                    50
# 6188                     3
# 6189                    10
# 6190                    10
#
# [12184 rows x 7 columns]

# %% [markdown]
# Creating a custom tag by POS tagging

# %%
matcher = Matcher(nlp.vocab)

ingredient_patterns = [
    [{"POS": "NOUN", "OP": "+"}],  # e.g., "chicken broth"
    [{"POS": "ADJ"}, {"POS": "NOUN", "OP": "+"}],  # e.g., "minced garlic"
    [{"POS": "PROPN"}, {"POS": "NOUN", "OP": "+"}],  # e.g., "Dijon mustard"
]

# Add patterns to the matcher
for i, pattern in enumerate(ingredient_patterns):
    matcher.add(f"Ingredient_{i}", [pattern])

# Custom component to identify ingredients
@Language.component("ingredient_component")
def ingredient_component(doc):
    matches = matcher(doc)
    spans = [Span(doc, start, end, label="INGREDIENT") for _, start, end in matches]
    spans = spacy.util.filter_spans(spans) 
    doc.ents = spans 
    return doc

nlp.add_pipe("ingredient_component", last=True)
# Out:
# <function __main__.ingredient_component(doc)>

# %% [markdown]
# # 1b. Applying NER

# %%
# List of common non-ingredient words
non_ingredient_words = {"cups", "cup", "tablespoons", "tablespoon", "teaspoons", "teaspoon", "ounce", "ounces", "pinch", "pound", "pounds", "stirring", "degrees", "room temperature"}

def extract_ingredients(text):
    doc = nlp(text)
    ingredients = []
    
    for ent in doc.ents:
        if ent.label_ == "INGREDIENT":
            ingredient_tokens = [token for token in ent if token.pos_ in ["NOUN", "PROPN", "ADJ"]]
            # Filter out non-ingredient words only if they are the first token
            if ingredient_tokens and ingredient_tokens[0].text.lower() not in non_ingredient_words:
                ingredient_name = " ".join([token.text for token in ingredient_tokens])
                if ingredient_name:  # Ensure non-empty strings
                    ingredients.append(ingredient_name)
    
    return ingredients

df['ingredient_names'] = df['recipe_Ingredients'].apply(lambda x: extract_ingredients(str(x)))

print(df['ingredient_names'].head())
# Out:
# 0    [tomatoes, purpose flour, clove garlic, cayenn...
# 1    [purpose flour, soda, powder, eggs, ripe avoca...
# 2                        [black pepper, butter, onion]
# 3    [kohlrabi bulbs, clove garlic, salt, pepper, P...
# 4             [egg, unsalted butter, room temperature]
# Name: ingredient_names, dtype: object

# %% [markdown]
# # 1c. Recipe - Ingredient pair saved

# %%
recipe_ingredient_pairs = []

for index, row in df.iterrows():
    recipe_id = row['recipe_id']
    for ingredient in row['ingredient_names']:
        recipe_ingredient_pairs.append((recipe_id, ingredient))

# Save the pairs to a .txt file
with open('recipe_ingredient_pairs.txt', 'w', encoding="utf-8") as file:
    for pair in recipe_ingredient_pairs:
        file.write(f"{pair[0]} - {pair[1]}\n")

print("Saved")
# Out:
# Saved

# %% [markdown]
# # 2a. Unique ingredients with their frequenceies saved

# %%
with open(recipe_ingredient_pair, 'r', encoding="utf-8") as f:
    recipe_text = f.read()

ingredient_freq = process_recipes(recipe_text)


# Save to CSV
save_to_csv(ingredient_freq, 'ingredient_frequencies.csv')
print("Frequencies saved to ingredient_frequencies.csv")
# Out:
# Frequencies saved to ingredient_frequencies.csv

# %% [markdown]
# # 2b.

# %%
recipe_sizes = df['ingredient_names'].apply(lambda x: len(x))
average_recipe_size = recipe_sizes.mean()

print(f"Average Recipe Size: {round(average_recipe_size)} ingredients")

plt.figure(figsize=(10, 6))
sns.histplot(recipe_sizes, bins=20, color='skyblue', kde=True)

plt.title("Recipe Size Distribution")
plt.xlabel("Recipe Size (Number of Ingredients)")
plt.ylabel("Number of Recipes")

plt.show()
# Out:
# Average Recipe Size: 8 ingredients

# %% [markdown]
# # 2c

# %%
recipe_sizes = np.array(recipe_sizes)
hist_data, bin_edges = np.histogram(recipe_sizes, bins=20, density=True)
cdf = np.cumsum(hist_data * np.diff(bin_edges))
cdf /= cdf[-1]

plt.figure(figsize=(10, 6))
plt.plot(bin_edges[1:], cdf, color='skyblue', marker='o', linestyle='-')

plt.title("Cumulative Recipe Size Distribution")
plt.xlabel("Recipe Size")
plt.ylabel("Cumulative Probability")

plt.show()

# %% [markdown]
# # 3a

# %%
ingredient_freq = pd.read_csv('ingredient_frequencies.csv')
ingredient_freq = ingredient_freq.sort_values(by='Frequency', ascending=False)

# Normalizing the frequency
total_frequency = ingredient_freq['Frequency'].sum()
ingredient_freq['Normalized Frequency'] = ingredient_freq['Frequency'] / total_frequency

ingredient_freq['Rank'] = range(1, len(ingredient_freq) + 1)

plt.figure(figsize=(10, 6))
plt.plot(ingredient_freq['Rank'], ingredient_freq['Normalized Frequency'], 'bo', label='Normalized Frequency')

plt.yscale('log')
plt.xscale('log')

plt.title("Frequency-Rank Distribution of Ingredients")
plt.xlabel("Rank")
plt.ylabel("Normalized Frequency")

plt.legend()
plt.show()
