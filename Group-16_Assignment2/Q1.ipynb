# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.12.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.2.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.4.1.post1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.8.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\saumil\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\saumil\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\saumil\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\saumil\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 15.2 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1

# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ### Preprocessing the data into a more suitable format

# %%
data = pd.read_csv("dataset/recipe_dataset.csv")
data = data.head(10000)
data = data.drop(data.columns[0], axis=1)

data
# Out:
#       recipe_id                                    recipe_name  \
# 0             1  Super Easy Slow Cooker Chicken Enchilada Meat
# 1             2                            Avocado Quick Bread
# 2             3               Quick and Easy Baked Fish Fillet
# 3             4                               Roasted Kohlrabi
# 4             5                            Custard Buttercream
# ...         ...                                            ...
# 9995       9996                             Earthquake Cookies
# 9996       9997                       Pistachio-Crusted Salmon
# 9997       9998                     Classic Shepherd&#39;s Pie
# 9998       9999              One-Pot Spaghetti with Meat Sauce
# 9999      10000                       Slow Cooker Cowboy Beans
#
#                                                     url  \
# 0     https://www.allrecipes.com/recipe/228367/super...
# 1     https://www.allrecipes.com/recipe/27341/avocad...
# 2     https://www.allrecipes.com/recipe/256348/quick...
# 3     https://www.allrecipes.com/recipe/203975/roast...
# 4     https://www.allrecipes.com/recipe/262379/custa...
# ...                                                 ...
# 9995  https://www.allrecipes.com/recipe/10904/earthq...
# 9996  https://www.allrecipes.com/recipe/269394/pista...
# 9997  https://www.allrecipes.com/recipe/217812/class...
# 9998  https://www.allrecipes.com/recipe/269004/one-p...
# 9999  https://www.allrecipes.com/recipe/242080/slow-...
#
#                                      recipe_Ingredients  \
# 0     2 cups chicken broth, 1 (14.5 ounce) can diced...
# 1     2.6666667461395 cups all-purpose flour, 1.5 te...
# 2     1 pound flounder fillets, 0.5 teaspoon salt, g...
# 3     4 kohlrabi bulbs, peeled, 1 tablespoon olive o...
# 4     1 egg, 1 cup white sugar, 0.5 cup milk, 1.3333...
# ...                                                 ...
# 9995  1 (18.25 ounce) package devil's food cake mix,...
# 9996  0.25 cup crushed pistachios, 2 tablespoons pan...
# 9997  1 tablespoon vegetable oil, 1 onion, chopped, ...
# 9998  1 pound ground Italian sausage, 1 small white ...
# 9999  1 pound ground beef, 0.5 pound bacon, chopped,...
#
#                                            Instructions               cuisine  \
# 0     Place chicken broth, tomatoes, flour, chili po...  ['Mexican Inspired']
# 1     Preheat the oven to 350 degrees F (175 degrees...          ['American']
# 2     Gather all ingredients. Preheat the oven to 40...          ['American']
# 3     Preheat the oven to 450 degrees F (230 degrees...          ['American']
# 4     Beat egg with a fork in a small, heavy saucepa...            ['German']
# ...                                                 ...                   ...
# 9995  Mix cake mix, eggs, shortening, and water in a...          ['American']
# 9996  Preheat the oven to 375 degrees F (190 degrees...          ['American']
# 9997  Preheat the oven to 350 degrees F (180 degrees...    ['Uk And Ireland']
# 9998  Combine ground sausage, onions, and garlic in ...           ['Italian']
# 9999  Gather the ingredients. Heat a large skillet o...          ['American']
#
#       Prep Time in Minutes
# 0                      480
# 1                       60
# 2                       25
# 3                       20
# 4                       10
# ...                    ...
# 9995                    10
# 9996                    15
# 9997                    35
# 9998                    30
# 9999                   190
#
# [10000 rows x 7 columns]

# %%
ingredients = []
with open('dataset/recipe_ingredient_pairs.txt', 'r', encoding='utf-8') as file:
    for line in file:
        # Split on the first occurrence of ' - ' to handle ingredients with hyphens
        recipe_id, ingredient = line.strip().split(' - ', 1)
        ingredients.append({'recipe_id': int(recipe_id), 'ingredient': ingredient})
    
ingredients_df = pd.DataFrame(ingredients)
ingredients_df
# Out:
#        recipe_id              ingredient
# 0              1                tomatoes
# 1              1           purpose flour
# 2              1            clove garlic
# 3              1          cayenne pepper
# 4              1                skinless
# ...          ...                     ...
# 93390      12184  miniature marshmallows
# 93391      12184                    milk
# 93392      12184               dash salt
# 93393      12184                   chips
# 93394      12184           peanut butter
#
# [93395 rows x 2 columns]

# %%
df = pd.merge(ingredients_df, data, on='recipe_id', how='inner')
df.drop(columns=['url','recipe_Ingredients','Instructions','cuisine','Prep Time in Minutes'], inplace=True)
df
# Out:
#        recipe_id        ingredient  \
# 0              1          tomatoes
# 1              1     purpose flour
# 2              1      clove garlic
# 3              1    cayenne pepper
# 4              1          skinless
# ...          ...               ...
# 76842      10000      kidney beans
# 76843      10000        lima beans
# 76844      10000            onions
# 76845      10000       brown sugar
# 76846      10000  prepared mustard
#
#                                          recipe_name
# 0      Super Easy Slow Cooker Chicken Enchilada Meat
# 1      Super Easy Slow Cooker Chicken Enchilada Meat
# 2      Super Easy Slow Cooker Chicken Enchilada Meat
# 3      Super Easy Slow Cooker Chicken Enchilada Meat
# 4      Super Easy Slow Cooker Chicken Enchilada Meat
# ...                                              ...
# 76842                       Slow Cooker Cowboy Beans
# 76843                       Slow Cooker Cowboy Beans
# 76844                       Slow Cooker Cowboy Beans
# 76845                       Slow Cooker Cowboy Beans
# 76846                       Slow Cooker Cowboy Beans
#
# [76847 rows x 3 columns]

# %% [markdown]
# # 1a

# %%
transactions = df.groupby('recipe_id')['ingredient'].apply(list).values.tolist()

te = TransactionEncoder() # Encode the list of ingredients (one hot)
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

min_support = 0.005  # 0.5% 
frequent_itemsets = apriori(df_encoded, min_support=min_support, use_colnames=True) # Using apriori

# %% [markdown]
# ### All Itemsets

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# Frequent itemsets of size 1
frequent_1_itemsets = frequent_itemsets[frequent_itemsets['length'] == 1]
print("Frequent Itemsets of Size 1:")
print(frequent_1_itemsets)

# Frequent itemsets of size 2
frequent_2_itemsets = frequent_itemsets[frequent_itemsets['length'] == 2]
print("\nFrequent Itemsets of Size 2:")
print(frequent_2_itemsets)

# Frequent itemsets of size 3
frequent_3_itemsets = frequent_itemsets[frequent_itemsets['length'] == 3]
print("\nFrequent Itemsets of Size 3:")
print(frequent_3_itemsets)
# Out:
# Frequent Itemsets of Size 1:
#       support           itemsets  length
# 0    0.006221                (%)       1
# 1    0.005117  (Cajun seasoning)       1
# 2    0.063710   (Cheddar cheese)       1
# 3    0.020668    (Dijon mustard)       1
# 4    0.005318  (Italian parsley)       1
# ..        ...                ...     ...
# 233  0.007425  (yellow cake mix)       1
# 234  0.007725   (yellow mustard)       1
# 235  0.024481     (yellow onion)       1
# 236  0.012441         (zucchini)       1
# 237  0.014548                (®)       1
#
# [238 rows x 3 columns]
#
# Frequent Itemsets of Size 2:
#       support                         itemsets  length
# 238  0.026889   (black pepper, Cheddar cheese)       2
# 239  0.006321  (cooking spray, Cheddar cheese)       2
# 240  0.006321          (Cheddar cheese, cream)       2
# 241  0.008327           (Cheddar cheese, eggs)       2
# 242  0.007124  (garlic powder, Cheddar cheese)       2
# ..        ...                              ...     ...
# 649  0.005819    (sour cream, unsalted butter)       2
# 650  0.008829         (sugar, unsalted butter)       2
# 651  0.006120             (sugar, white sugar)       2
# 652  0.010635   (white sugar, unsalted butter)       2
# 653  0.005318    (whole milk, unsalted butter)       2
#
# [416 rows x 3 columns]
#
# Frequent Itemsets of Size 3:
#       support                                           itemsets  length
# 654  0.008227             (black pepper, ground, Cheddar cheese)       3
# 655  0.005217              (black pepper, onion, Cheddar cheese)       3
# 656  0.005217            (black pepper, Cheddar cheese, package)       3
# 657  0.006321      (black pepper, Cheddar cheese, purpose flour)       3
# 658  0.009933               (black pepper, salt, Cheddar cheese)       3
# ..        ...                                                ...     ...
# 791  0.006221        (powder, room temperature, unsalted butter)       3
# 792  0.009732  (room temperature, unsalted butter, purpose fl...       3
# 793  0.006321            (sugar, unsalted butter, purpose flour)       3
# 794  0.005117                (sugar, white sugar, purpose flour)       3
# 795  0.008127      (white sugar, unsalted butter, purpose flour)       3
#
# [142 rows x 3 columns]

# %% [markdown]
# ### Saved to CSV

# %%
frequent_1_itemsets.to_csv('Q1_outputs/1_size_itemsets.csv', index=False)
frequent_2_itemsets.to_csv('Q1_outputs/2_size_itemsets.csv', index=False)
frequent_3_itemsets.to_csv('Q1_outputs/3_size_itemsets.csv', index=False)

# %% [markdown]
# # 1b

# %% [markdown]
# ### Top 20 Itemsets

# %%
# Top 20 itemsets of size 1
top_1_itemsets = frequent_itemsets[frequent_itemsets['length'] == 1].nlargest(20, 'support')
print("Top 20 Itemsets of Size 1:")
print(top_1_itemsets)

# Top 20 itemsets of size 2
top_2_itemsets = frequent_itemsets[frequent_itemsets['length'] == 2].nlargest(20, 'support')
print("\nTop 20 Itemsets of Size 2:")
print(top_2_itemsets)

# Top 20 itemsets of size 3
top_3_itemsets = frequent_itemsets[frequent_itemsets['length'] == 3].nlargest(20, 'support')
print("\nTop 20 Itemsets of Size 3:")
print(top_3_itemsets)
# Out:
# Top 20 Itemsets of Size 1:
#       support           itemsets  length
# 26   0.323066     (black pepper)       1
# 167  0.230461    (purpose flour)       1
# 180  0.184308             (salt)       1
# 35   0.121601      (brown sugar)       1
# 72   0.117287             (eggs)       1
# 151  0.105849            (onion)       1
# 51   0.091903           (cloves)       1
# 225  0.091201      (white sugar)       1
# 107  0.090298           (ground)       1
# 97   0.081971    (garlic powder)       1
# 165  0.081569           (powder)       1
# 123  0.081369      (kosher salt)       1
# 214  0.077054  (unsalted butter)       1
# 154  0.076753          (package)       1
# 127  0.072138       (large eggs)       1
# 8    0.070031  (Parmesan cheese)       1
# 2    0.063710   (Cheddar cheese)       1
# 69   0.059496              (egg)       1
# 114  0.059296             (inch)       1
# 213  0.056386         (tomatoes)       1
#
# Top 20 Itemsets of Size 2:
#       support                          itemsets  length
# 371  0.112371              (black pepper, salt)       2
# 336  0.089295            (black pepper, ground)       2
# 529  0.075048                    (ground, salt)       2
# 606  0.067623           (powder, purpose flour)       2
# 357  0.056185             (black pepper, onion)       2
# 490  0.055082             (eggs, purpose flour)       2
# 314  0.052975            (cloves, black pepper)       2
# 364  0.048360     (black pepper, purpose flour)       2
# 331  0.047457     (black pepper, garlic powder)       2
# 413  0.045350      (brown sugar, purpose flour)       2
# 345  0.045049       (black pepper, kosher salt)       2
# 602  0.044848                    (salt, pepper)       2
# 621  0.041236  (unsalted butter, purpose flour)       2
# 624  0.039731      (white sugar, purpose flour)       2
# 565  0.034915       (purpose flour, large eggs)       2
# 259  0.034514   (black pepper, Parmesan cheese)       2
# 480  0.031203              (egg, purpose flour)       2
# 456  0.030200                    (cloves, salt)       2
# 586  0.029297                     (salt, onion)       2
# 359  0.028895           (black pepper, package)       2
#
# Top 20 Itemsets of Size 3:
#       support                                       itemsets  length
# 711  0.074947                   (black pepper, ground, salt)       3
# 758  0.022675                  (powder, eggs, purpose flour)       3
# 690  0.019565                   (cloves, black pepper, salt)       3
# 724  0.018862                    (black pepper, salt, onion)       3
# 743  0.016655           (powder, brown sugar, purpose flour)       3
# 788  0.015953       (powder, purpose flour, unsalted butter)       3
# 790  0.015752           (powder, white sugar, purpose flour)       3
# 728  0.014849            (black pepper, salt, purpose flour)       3
# 708  0.014749                  (black pepper, ground, onion)       3
# 685  0.014046                 (cloves, black pepper, ground)       3
# 776  0.013846            (powder, purpose flour, large eggs)       3
# 669  0.013545          (black pepper, salt, Parmesan cheese)       3
# 756  0.012842                   (powder, egg, purpose flour)       3
# 710  0.012742          (black pepper, ground, purpose flour)       3
# 764  0.012742             (white sugar, eggs, purpose flour)       3
# 768  0.012642                          (ground, onion, salt)       3
# 746  0.012441  (brown sugar, unsalted butter, purpose flour)       3
# 751  0.012441                         (cloves, ground, salt)       3
# 780  0.011739   (unsalted butter, large eggs, purpose flour)       3
# 739  0.011438             (eggs, brown sugar, purpose flour)       3

# %% [markdown]
# ### Saved to CSV

# %%
top_1_itemsets.to_csv('Q1_outputs/top20_1_itemsets.csv', index=False)
top_2_itemsets.to_csv('Q1_outputs/top20_2_itemsets.csv', index=False)
top_3_itemsets.to_csv('Q1_outputs/top20_3_itemsets.csv', index=False)

# %% [markdown]
# # 1c
#
# **Support:**
# 1. Support is a metric used in association rule mining to measure the frequency of occurrence of an itemset in a dataset
# 2. It is defined as the proportion of transactions (in this case, recipes) that contain the item (ingredient) or itemset.
#
# 3. $Support = {A\over B}$
# A = Number of recipes containing ingredient x
# B = Total number of recipes
#
# [Reference](https://codefinity.com/courses/v2/a7e17f02-2cc9-4b92-abe0-cc8710d7011e/d2fce24c-4b70-427a-815a-afeb7ae6e604/bf978c9d-0090-4671-a662-a7277eb34e7d)
#
# **Confidence:**
# 1. Confidence is a measure of the likelihood that an itemset will appear if another itemset appears.
# 2. It indicates the proportion of the transactions (recipes) which contain ingredient A or item A along with ingredient B or item B.
# 3. $
# \text{Confidence}(X \rightarrow Y) = \frac{\text{Support}(X \cup Y)}{\text{Support}(X)}
# $
# X & Y are ingredients
#
# [Reference](https://www.geeksforgeeks.org/what-is-support-and-confidence-in-data-mining/#:~:text=Support%20is%20a%20measure%20of,the%20total%20number%20of%20transactions.)
#
# **Briefly:**
# Support shows how common an item or itemset is in the dataset.
# Confidence shows how likely an item or itemset x is to appear when another item or itemset y is already present in the transaction.
